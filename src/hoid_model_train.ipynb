# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Thesis_Workspace
# !ls -1ah

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
from ultralytics.data.converter import convert_ndjson_to_yolo
import torch

using_gpu = None
if torch.cuda.is_available():
    print(True)
    print(torch.cuda.current_device())
    print(torch.cuda.get_device_name(0))
    using_gpu=0
else:
    print(False)
    print("No GPU available")
    using_gpu="cpu"
# Out:
# True
# 0
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
# ndjson_dataset = "detect_dataset.ndjson"
# await convert_ndjson_to_yolo(f"ndjson/{ndjson_dataset}", "ndjson/")

# %%
model = YOLO("runs/detect/train-10/weights/last.pt")

# model.train(
#     data="datasets/cctv/data.yaml",
#     device=0,
#     amp=True,
#     epochs=100,
#     patience=20,
#     imgsz=640,
#     batch=4,
#     workers=1,
#     plots=True
# )

model.train(data="datasets/cctv/data.yaml", resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.4.120 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.21  Python-3.12.7 torch-2.10.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
