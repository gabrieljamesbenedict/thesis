# %%
all_vids = ["vid30","vid11","vid12","vid13","vid10","vid14","vid15","vid16","vid17","vid18","vid19","vid20","vid21","vid22","vid23","vid24","vid25","vid26","vid27","vid28","vid29","vid31","vid32","vid33","vid34","vid35","vid36","vid37","vid01","vid02","vid03","vid04","vid05","vid06","vid07","vid08","vid09"]
all_vids_set = sorted(set(all_vids))

print(all_vids_set)
# Out:
# ['vid01', 'vid02', 'vid03', 'vid04', 'vid05', 'vid06', 'vid07', 'vid08', 'vid09', 'vid10', 'vid11', 'vid12', 'vid13', 'vid14', 'vid15', 'vid16', 'vid17', 'vid18', 'vid19', 'vid20', 'vid21', 'vid22', 'vid23', 'vid24', 'vid25', 'vid26', 'vid27', 'vid28', 'vid29', 'vid30', 'vid31', 'vid32', 'vid33', 'vid34', 'vid35', 'vid36', 'vid37']

# %%
all_processed_vids_string = """vid30   1897/1897     [########################################] 100.00% 93.23s 
vid11   3799/3799     [########################################] 100.00% 147.65s
vid12   9009/9009     [########################################] 100.00% 346.39s
vid13   8305/8305     [########################################] 100.00% 325.30s
vid10   35843/35843   [########################################] 100.00% 1362.05s
vid14   579/579       [########################################] 100.00% 26.63s 
vid15   2394/2394     [########################################] 100.00% 92.49s 
vid16   1809/1809     [########################################] 100.00% 71.50s 
vid17   6203/6203     [########################################] 100.00% 237.28s
vid18   715/715       [########################################] 100.00% 30.47s 
vid19   3610/3610     [########################################] 100.00% 151.33s
vid20   1889/1889     [########################################] 100.00% 79.29s 
vid21   3382/3382     [########################################] 100.00% 140.83s
vid22   9039/9039     [########################################] 100.00% 365.12s
vid23   12512/12512   [########################################] 100.00% 477.42s
vid24   1320/1320     [########################################] 100.00% 53.71s 
vid25   375/375       [########################################] 100.00% 16.05s 
vid26   1809/1809     [########################################] 100.00% 72.39s 
vid27   1799/1799     [########################################] 100.00% 72.06s 
vid28   1803/1803     [########################################] 100.00% 73.32s 
vid29   438/438       [########################################] 100.00% 19.25s 
vid31   1849/1849     [########################################] 100.00% 75.44s 
vid32   1941/1941     [########################################] 100.00% 79.34s 
vid33   2031/2031     [########################################] 100.00% 79.48s 
vid34   1799/1799     [########################################] 100.00% 71.65s 
vid35   1054/1054     [########################################] 100.00% 37.00s 
vid36   612/612       [########################################] 100.00% 22.98s 
vid37   11161/11161   [########################################] 100.00% 379.37s
vid01   3921/3921     [########################################] 100.00% 152.49s
vid02   693/693       [########################################] 100.00% 28.49s 
vid03   2189/2189     [########################################] 100.00% 84.66s 
vid04   18494/35843   [####################--------------------] 51.60%  705.68s"""

all_processed_vids = all_processed_vids_string.split("\n")
all_processed_vids = [e[:5] for e in all_processed_vids]

# %%
missing_vids = set(all_vids_set) - set(all_processed_vids)
print(sorted(missing_vids))
# Out:
# ['vid05', 'vid06', 'vid07', 'vid08', 'vid09']

# %%
asdasd = ["vid01","vid02","vid03","vid10","vid11","vid12","vid13","vid14","vid15","vid16","vid17","vid18","vid19","vid20","vid21","vid22","vid23","vid24","vid25","vid26","vid27","vid28","vid29","vid30","vid31","vid32","vid33","vid34","vid35","vid36","vid37"]
missing_vids2 = set(all_vids_set) - set(asdasd)

print(sorted(missing_vids2))
# Out:
# ['vid04', 'vid05', 'vid06', 'vid07', 'vid08', 'vid09']
